# %% [markdown]
# # Conditional Statement (If-else)
#
# Conditional statement allow you to make decisions based on the values of variables or the result of comparisons. That is why they are also called decision making statements.
#
# In Python, there are three forms of the conditional statement.
#
# - if statement
# - if...else statement
# - if...elif...else statement

# %% [markdown]
# ### If Statement
# The if statement allows you to execute a block of code if a certain condition is true.
#
# __Syntax__:
#
# if condition:
#
#     block of code/ statements
#
# - If the condition satify, then the block of code or statements inside the body of the if execute.
# - If the condition not satisfy, then the block of code or statements inside the body of the if execute.
#
# ![image-2.png](attachment:image-2.png)
#
# __Note__: There are two most important point that need to be remember while using if statement.
# 1. colon(:)
# 2. Indentation
#
# If any of these two points skipped, then the code will raise an error. So, while using "if statements", always use colon and a proper indentation at a required place.

# %%
num = 2         # The value of num is assigned as 2.
if num < 5: #Here, we are checking the condition. Since 2 is less than 5 which means the statement inside the "if" will execute.
    print("I am inside the code.")   # Here, this statement is written inside the if body.
    
print("I am outside the code")   # Here, this statement is written outside the if body which means no matter whether the 
                                 # condition is true or not, this statement will 100% execute.
# Out:
# I am inside the code.
# I am outside the code

# %%
num = 8             # The value of num is assigned as 8.
if num < 5: #Since 8 is greater than 5 which means the statement inside "if" will not execute as condition doesn't satisfied.
    print("I am inside the code.")   # Here, this statement is written inside the if body. It will not execute.
    
print("I am outside the code")   # Here, You can observe that only the code written outside the if body executed but the code
                                 # writtten inside the if body was not executed because of the incorrect condition.
# Out:
# I am outside the code

# %%
num = 8
if num < 5     #Here, i didn't use colon that is why this code will raise an error.
    print("I am inside the code.") 
    
print("I am outside the code")
# Out:
#   Cell In[3], line 2
#     if num < 5     #Here, i didn't use colon that is why this code will raise an error.
#                    ^
# SyntaxError: expected ':'

# %%
num = 8
if num < 5:     
print("I am inside the code.")     #Here I didn't give indentation after using if statement that is why it raise an error.
    
print("I am outside the code")
# Out:
#   Cell In[4], line 3
#     print("I am inside the code.")     #Here I didn't give indentation after using if statement that is why it raise an error.
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %% [markdown]
# __Note__: The condition that we used in if statement returns either __True__ or __False__. This means if the condition is TRUE, then the code written inside the if body will execute but if the condition is FALSE, then the code written inside the if body will not execute.

# %%
if True:
    print("This will execute as condition is TRUE.")
print("Outside the if body means this will execute.")

#Here both the statements (inside and outside) executed.
# Out:
# This will execute as condition is TRUE.
# Outside the if body means this will execute.

# %%
if False:
    print('This will not execute as condition is FALSE.')
print("Outside the if body means this will execute.")
#Here only the outside statement executed.
# Out:
# Outside the if body means this will execute.

# %%
if 1:
    print("1 is equivalent to True.")
#Here 1 means True that is why inside statement executed. Note: Any number except 0 means True.
# Out:
# 1 is equivalent to True.

# %%
if 0:
    print("0 is equivalent to False.")
#Here there is no output as 0 means False that is why nothing executed.

# %%
if 5-5:         #Here 5-5 = 0 which is equivalent to False.
    print("Nothing will execute.")

# %%
if 5-2:          #Here 5-2 = 3 which is a positive number but not 0.
    print("This will execute as any number except 0 means True.")
# Out:
# This will execute as any number except 0 means True.

# %%
if 2-5:         #Here 2-5 = -3 which is a negative number but not 0.
    print("This will execute as any number except 0 means True.")
# Out:
# This will execute as any number except 0 means True.

# %% [markdown]
# __Note__: We can use Comparsion operators (>, <, ==, !=, <=, >=) for condition. Also, we can merge two or more condition using logical operators (and, or, not).

# %% [markdown]
# ### Comparison operator used in Condtion:-

# %%
if 2 < 5:
    print("I used < (Less than) operator in the condition.")
    print('2 is less than 5.')
# Out:
# I used < (Less than) operator in the condition.
# 2 is less than 5.

# %%
if 8 > 5:
    print("I used > (Greater than) operator in the condition.")
    print('8 is greater than 5.')
# Out:
# I used > (Greater than) operator in the condition.
# 8 is greater than 5.

# %%
if 5 == 5:
    print("I used == (Equal to) operator in the condition.")    
    print('5 is equal to 5.')
# Out:
# I used == (Equal to) operator in the condition.
# 5 is equal to 5.

# %% [markdown]
# __NOTE__: Equal to operator is represented by == (double equal) not = (single operator). Most of the beginner make this mistakes while equating something using equal to operator. = is an assignment operator.

# %%
if 2 != 5:
    print("I used != (Not Equal to) operator in the condition.")
    print('2 is not equal to 5.')
# Out:
# I used != (Not Equal to) operator in the condition.
# 2 is not equal to 5.

# %%
if 2 <= 5:
    print("I used <= (Less than or equal to) operator in the condition.")
    print('2 is less than or equal to 5.')
# Out:
# I used <= (Less than or equal to) operator in the condition.
# 2 is less than or equal to 5.

# %%
if 8 >= 5:
    print("I used != (Greater than or equal to) operator in the condition.")
    print('8 is greater than or equal to 5.')
# Out:
# I used != (Greater than or equal to) operator in the condition.
# 8 is greater than or equal to 5.

# %% [markdown]
# ### Logical operator and comparison operator used in condtion:-

# %%
if 2 < 5 and 2 > 5:
    print("I used 'and' operator which result true when both the conditions are true else return false.")
    
print("Since True and False is equal to False that is why the inside statement will not execute..")
# Out:
# Since True and False is equal to False that is why the inside statement will not execute..

# %%
if 2 < 5 or 2 > 5:
    print("I used 'or' operator which result true when any of the condition is True else return false.")
    
print("Since True and False is equal to True that is why the inside statement will execute..")
# Out:
# I used 'or' operator which result true when any of the condition is True else return false.
# Since True and False is equal to True that is why the inside statement will execute..

# %%
if not 5:
    print("Not 5 means False that is why inside code will not execute.")
    
print("This is outside the if body.")
# Out:
# This is outside the if body.

# %%
# We can use empty list or anything that is empty(zero elements) as a condition.
l1=[]
if l1:
    print('List is empty.')
print('Here the list is empty that is why it return False and inside statement will not execute')
# Out:
# Here the list is empty that is why it return False and inside statement will not execute

# %%
l1=[1,2,3,4,5]
if l1:
    print('List is not empty.')
# Out:
# List is not empty.

# %%
# We can also compare datatype to check the condition.
if '2'==2:
    print("It will execute.")
    
print("The datatype of 's' is string whereas the datatype of 2 is Integer. The condition return false.")
# Out:
# The datatype of 's' is string whereas the datatype of 2 is Integer. The condition return false.

# %%
if "hello":
    print("This will execute.")
    
# Here, "hello" is used as a condition which return True.
# Out:
# This will execute.

# %% [markdown]
# ### If..else Statement
# If the condition is true, the if block code is executed and if the condition is false, the else block code is executed.
#
# __Syntax__:
#
# if condition:
#
#     block of code/ statements
#
# else:
#
#     block of code/ statements
#
# ![image.png](attachment:image.png)

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print('You can cast the vote.')
else:
    print('You cannot cast the vote.')
# Out:
# Enter your age: 12
# You cannot cast the vote.

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print('You can cast the vote.')
else:
    print('You cannot cast the vote.')
# Out:
# Enter your age: 21
# You can cast the vote.

# %% [markdown]
# __Note__: Here you can see when i entered 12 as age, then condition return False that is why the code written inside the "if" body was not executed whereas the code written inside the 'else' body was executed. But when i entered 21 as age, then condition return True that is why the code written inside the "if" body was executed whereas the code written inside the 'else' body was notexecuted. This implies that "else" works only when the condition used in "if" return false.

# %%
num = int(input("Enter any number: "))
if num > 0:
    print('The number is positive.')
else:
    print('The number is negative.')
# Out:
# Enter any number: 5
# The number is positive.

# %%
num = int(input("Enter any number: "))
if num > 0:
    print('The number is positive.')
else:
    print('The number is negative.')
# Out:
# Enter any number: -5
# The number is negative.

# %% [markdown]
# __Note__: Here, don't forget to use colon and indentation else it will return error.

# %% [markdown]
# ### If..elif..else Statement
#
# If the condition is true, the if block code is executed and if the condition is false, the else block code is executed.
#
# __Syntax__:
#
# if condition:
#
#     block of code/ statements
#
# elif condition:
#
#     block of code/ statements
#
#  else:
#
#     block of code/ statements
#
# ![image.png](attachment:image.png)
#
# __Note__: In elif we again use condtion but in else we didn't use any condtion which means the condition used in "if" return False, then the python interpretor goes on "elif condition" and check this condition, if condition return True then the statement written inside the 'elif' will execute but if the condition used in 'elif' return False, then the python interpretor go on else and here there is no condition which means any statement written inside else will definitely execute.

# %%
num = int(input("Enter any number: "))
if num > 0:
    print('The number is positive.')
elif num < 0:
    print('The number is negative')
else:
    print('The number is 0.')

# Here the number 5 is greater than 0 that is why this number is positive and the statement written inside "if" executed.
# Out:
# Enter any number: 5
# The number is positive.

# %%
num = int(input("Enter any number: "))
if num > 0:
    print('The number is positive.')
elif num < 0:
    print('The number is negative')
else:
    print('The number is 0.')
    
# Here the number -5 is less than 0 that is why this number is negatove and the statement written inside "elif" executed.
# Out:
# Enter any number: -5
# The number is negative

# %%
num = int(input("Enter any number: "))
if num > 0:
    print('The number is positive.')
elif num < 0:
    print('The number is negative')
else:
    print('The number is 0.')
# Here the number 0 does not satisfy the condition used in either 'if' or 'elif', that is why code written inside else executed.
# Out:
# Enter any number: 0
# The number is 0.

# %% [markdown]
# __Note__: We can use __any number___ of '__elif__' in between '__if__' and '__else__', but there can be __only one or zero__ '__else__' for a particular '__if__' condition.

# %% [markdown]
# ## Nested if statements
# When we use if, if..else, if..elif..else inside other if, if..else, if..elif..else, then this situation is called nested if statements.

# %%
n=int(input("Enter any number: "))
if n % 2 == 0:
    if n < 10:            # here we are using nested if..else
        print('The number is even and less than 10.')
    elif n == 10:
        print('The number is even and equal to 10.')
    else:
        print('The number is even and greater than 10.')
else:
    print(f'The number {n} is not even.')
# Out:
# Enter any number: 12
# The number is even and greater than 10.

# %%
n=int(input("Enter any number less than 10: "))
if n % 2 == 0:
    if n % 3 ==0:
        if n % 4 ==0:
            if n % 9 == 0:
                print(f'The number {n} is divisible by 2, 3, 4, 6 and 9.')
            elif n % 8 == 0:
                print(f'The number {n} is divisible by 2, 3, 4, 6 and 8.')
            else:
                print(f'The number {n} is divisible by 2, 3, 4 and 6.')
        elif n % 9 ==0:
            print(f'The number {n} is divisible by 2, 3, 6 and 9.')
        else:
            print(f'The number {n} is divisible by 2, 3, and 6.')
    elif n % 4 == 0:
        if n % 8 == 0:
            if n % 5 == 0:
                print(f'The number {n} is divisible by 2, 4, 5 and 8.')
            else:
                print(f'The number {n} is divisible by 2, 4 and 8.')
        else:
            print(f'The number {n} is divisible by 2 and 4.')
    elif n % 5 == 0:
        print(f'The number {n} is divisible by 2 and 5.')
    else:
        print(f'The number {n} is divisible by 2.')
elif n % 3 == 0:
    if n % 5 == 0:
        if n % 9 == 0:
            print(f'The number {n} is divisible by 3, 5 and 9.')
        else:
            print(f'The number {n} is divisible by 3 and 5.')
    elif n % 7 == 0:
        print(f'The number {n} is divisible by 3 and 7.')
    elif n % 9 == 0:
        print(f'The number {n} is divisible by 3 and 9.')
    else:
        print(f'The number {n} is divisible by 3.')
elif n % 5 == 0:
    if n % 7 ==0:
        print(f'The number {n} is divisible by 5 and 7.')
    else:
        print(f'The number {n} is divisible by 5.')    
elif n % 7 == 0:
    print(f'The number {n} is divisible by 7.')
else:
    print(f'The number {n} is a prime number.')
# Out:
# Enter any number less than 10: 48
# The number 48 is divisible by 2, 3, 4, 6 and 8.

# %% [markdown]
# __Note__: Please take care of 'if' and its corresponding 'elif' and 'else', otherwise you can face problem.

# %% [markdown]
# ## if else using membership operator (in, not in)  with List and Tuple.

# %%
l=[1,2,3,4,5,6]
n=int(input("Enter any number: "))
if n in l:
    print(f'The number {n} is in the list.')
    print(f"The number {n} is at index {l.index(n)}.")
else:
    print(f'The number {n} is not in the list.')
# Out:
# Enter any number: 4
# The number 4 is in the list.
# The number 4 is at index 3.

# %%
t=(1,2,3,4,5,6)
n=int(input("Enter any number: "))
if n in t:
    print(f'The number {n} is in the tuple.')
    print(f"The number {n} is at index {l.index(n)}.")
else:
    print(f'The number {n} is not in the tuple.')
# Out:
# Enter any number: 9
# The number 9 is not in the tuple.

# %% [markdown]
# ## if else using membership operator (in, not in)  with Dictionary.

# %%
d={'name':'Abhi',
   'course':'DBDA',
   'location':'Ghaziabad'
  }
query = input('Enter the key: ')
if query in d:
    print(f"The key '{query}' is in the dictionary.")
    print(f"The value of key is '{d[query]}'.")
else:
    print("The key is not in the dictionary.")
# Out:
# Enter the key: name
# The key 'name' is in the dictionary.
# The value of key is 'Abhi'.

# %% [markdown]
# ## Some basic programs using if..else

# %%
#wap to check whether the given number is even or odd.
num = int(input("Enter the number: "))  
if num%2 == 0:  
    print(f"The entered {num} is even.")  
else:  
    print(f"The entered {num} is odd.")
# Out:
# Enter the number: 5
# The entered 5 is odd.

# %%
# wap to grade the marks of students.
marks = int(input("Enter the marks? "))  
if marks > 85 and marks <= 100:
    print("Congrats ! you scored grade A.")  
elif marks > 60 and marks <= 85:
    print("You scored grade B +.")  
elif marks > 40 and marks <= 60:
    print("You scored grade B.")  
elif (marks > 30 and marks <= 40):
    print("You scored grade C.")  
else:
    print("Sorry you are fail ?")
# Out:
# Enter the marks? 86
# Congrats ! you scored grade A.

# %% [markdown]
# https://github.com/Abhishekk-Git`
